# %%
import pandas as pd

# %%
df_roles_s3 = pd.read_excel('./data/Rôles.xlsx', sheet_name='Semaine3', index_col='Nom')
df_roles_s4 = pd.read_excel('./data/Rôles.xlsx', sheet_name='Semaine4', index_col='Nom')
df_roles_s5 = pd.read_excel('./data/Rôles.xlsx', sheet_name='Semaine5', index_col='Nom')

# %%
df_roles_s5
# Out:
#                                    Projet  \
# Nom
# Camille CABRI                       Autre
# Amine SENOUCI                       Autre
# Remy Garcia                         Autre
# Gabriel FEDOU                       Autre
# Camille MIRIO                Enseignement
# Lassina TOURRE               Enseignement
# LAURENT Augustin                  BobbyHR
# Hugo BOUSSARD                     BobbyHR
# Tessa ROCHE-QUARRE                BobbyHR
# Margaux PIERRE                    BobbyHR
# HAO Yifan                             EMC
# WANG YANPEI                           EMC
# Medhi BACCOUR                         EMC
# Abderrhaman Mohamed Mahmoud           EMC
# Marouane Khoufid                      EMC
# Gabriel PAPALIA                       EMC
# Tylan TOMASINA                      Autre
# SAMI CARI                           Autre
# Léopold BULLOT                        CGR
# Hind NAOUI                            CGR
# Mamadou moussa DIALLO                 CGR
# ...

# %%
df_besoin_s4 = pd.read_excel('./data/Besoins.xlsx', sheet_name='Semaine4', index_col='Rôles')

# %%
df_besoin_s4['Nombre de ressources M1'] = df_besoin_s4['Nombre de ressources M1'].fillna(0)
df_besoin_s4['Nombre de ressources M2'] = df_besoin_s4['Nombre de ressources M2'].fillna(0)

# %%
df_besoin_s4
# Out:
#                                 Rôle Secondaire  Nombre de ressources M1  \
# Rôles
# Relation client                             Yes                      0.0
# Equipe Outils                               Yes                      0.0
# Chef Projet EMC                              No                      1.0
# Responsable Technique EMC                    No                      1.0
# Equipe EMC                                   No                      0.0
# Chef Projet CGR                              No                      1.0
# Responsable Technique CGR                    No                      1.0
# Equipe CGR                                   No                      0.0
# Chef Projet Bobby HR                         No                      1.0
# Responsable Technique Bobby HR               No                      1.0
# Equipe Bobby HR                              No                      0.0
# Responsable Formation  M1                   Yes                      0.0
# ...

# %%
df_besoin_s4_test = pd.read_excel('./data/Besoins_testFormat.xlsx', sheet_name='Semaine4', index_col='Projet')

# %%
df_besoin_s4_test
# Out:
#                               Rôles Rôle Secondaire  Nombre de ressources M1  \
# Projet
# Relation client       Collaborateur             Yes                      NaN
# Equipe Outils         Collaborateur             Yes                      NaN
# EMC                              PO              No                      1.0
# EMC                              SM              No                      1.0
# EMC                   Collaborateur              No                      NaN
# CGR                              PO              No                      1.0
# CGR                              SM              No                      1.0
# CGR                   Collaborateur              No                      NaN
# BobbyHR                          PO              No                      1.0
# BobbyHR                          SM              No                      1.0
# BobbyHR               Collaborateur              No                      NaN
# ...
